# %% [markdown]
# <a href="https://colab.research.google.com/github/EminIsmayilzada/Machine-Learning/blob/main/pandasDiv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

cars=pd.Series(['BMW', 'Tesla', 'Bugatti'])
cars
# Out:
# 0        BMW
# 1      Tesla
# 2    Bugatti
# dtype: object

# %%
colors=pd.Series(['Blue', 'Red', 'Black'])
colors
# Out:
# 0     Blue
# 1      Red
# 2    Black
# dtype: object

# %%
cars=pd.DataFrame({'Make': cars, 'Color': colors})
cars
# Out:
#       Make  Color
# 0      BMW   Blue
# 1    Tesla    Red
# 2  Bugatti  Black

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2024-12-03 07:09:53--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-12-03 07:09:53 (16.5 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
df=pd.read_csv("car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
df[['Make', 'Colour', 'Price']]
# Out:
#      Make Colour       Price
# 0  Toyota  White   $4,000.00
# 1   Honda    Red   $5,000.00
# 2  Toyota   Blue   $7,000.00
# 3     BMW  Black  $22,000.00
# 4  Nissan  White   $3,500.00
# 5  Toyota  Green   $4,500.00
# 6   Honda   Blue   $7,500.00
# 7   Honda   Blue   $7,000.00
# 8  Toyota  White   $6,250.00
# 9  Nissan  White   $9,700.00

# %%
df['Make']== 'Toyota'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Make, dtype: bool

# %%
df[df['Make']== 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df[(df['Make']== 'Toyota') & (df['Odometer (KM)']<70000)]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
